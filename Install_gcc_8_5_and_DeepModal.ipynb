# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive');
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Prepare Environment to Install GCC-8.5.0

# %%
"""
libgmp-dev: This is the development library for the GNU Multiple Precision Arithmetic Library (GMP), a free library for arbitrary precision arithmetic, operating on signed integers, rational numbers, and floating-point numbers.
libmpfr-dev: This is the development library for the MPFR library, which is a C library for multiple-precision floating-point computations with correct rounding.
libmpc-dev: This is the development library for MPC, a C library for the arithmetic of complex numbers with arbitrarily high precision and correct rounding of the result.

The command installs the development versions of these libraries, which are typically used for compiling and developing software that depends on these libraries.
"""
# !sudo apt-get install -y libgmp-dev libmpfr-dev libmpc-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libgmp-dev is already the newest version (2:6.2.1+dfsg-3ubuntu1).
# libmpc-dev is already the newest version (1.2.1-2build1).
# libmpfr-dev is already the newest version (4.1.0-3build3).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.

# %%
# %ls
# Out:
# libiomp5_db.so                     libmkl_scalapack_ilp64.so.2*       libtbbbind_2_0.so*
# libiomp5.so                        libmkl_scalapack_lp64.so.2*        libtbbbind_2_0.so.3*
# libiompstubs5.so                   libmkl_sequential.so.2*            libtbbbind_2_0.so.3.11*
# libmkl_avx2.so.2*                  libmkl_tbb_thread.so.2*            libtbbbind_2_5.so*
# libmkl_avx512.so.2*                libmkl_vml_avx2.so.2*              libtbbbind_2_5.so.3*
# libmkl_avx.so.2*                   libmkl_vml_avx512.so.2*            libtbbbind_2_5.so.3.11*
# libmkl_blacs_intelmpi_ilp64.so.2*  libmkl_vml_avx.so.2*               libtbbbind.so*
# libmkl_blacs_intelmpi_lp64.so.2*   libmkl_vml_cmpt.so.2*              libtbbbind.so.3*
# libmkl_blacs_openmpi_ilp64.so.2*   libmkl_vml_def.so.2*               libtbbbind.so.3.11*
# libmkl_blacs_openmpi_lp64.so.2*    libmkl_vml_mc3.so.2*               libtbbmalloc_proxy.so*
# ...

# %%
# %cd ..
# Out:
# /usr/local

# %%
# %ls
# Out:
# bin/    cuda@     cuda-11.8/  games/               include/  lib64/      man@   share/
# colab/  cuda-11@  etc/        _gcs_config_ops.so/  lib/      licensing/  sbin/  src/

# %%
# %cd usr/local/lib

# %%
"""
the command !ls -l libtbb* will list all files and directories in the long listing format that begin with libtbb in the current directory.
This is typically used to check the details of libraries related to Intel Threading Building Blocks (TBB), which are often named with the libtbb prefix.
"""
# !ls -l libtbb*

# %%
"""
The commands are Linux shell commands for creating symbolic links between files.
Symbolic links (often called "symlinks") are like shortcuts or references to the actual file.
These commands are typically used to ensure that software looking for a specific version of a library can find it,
even if the actual installed version has a slightly different name.
"""
# !ln -sf libtbbbind_2_0.so.3 libtbbbind_2_0.so
# !ln -sf libtbbmalloc.so.2 libtbbmalloc.so
# !ln -sf libtbbbind_2_5.so.3 libtbbbind_2_5.so
# !ln -sf libtbbbind.so.3 libtbbbind.so
# !ln -sf libtbb.so.12 libtbb.so.12.10
# !ln -sf libtbbmalloc_proxy.so.2 libtbbmalloc_proxy.so

# %%
# %cd ..
# %cd ..
# %cd ..
# !pwd
# Out:
# /usr
# /
# /
# /

# %%
# %ls
# Out:
# bin@                        datalab/  lib@     media/                    proc/        sbin@  tools/
# boot/                       dev/      lib32@   mnt/                      python-apt/  srv/   usr/
# content/                    etc/      lib64@   NGC-DL-CONTAINER-LICENSE  root/        sys/   var/
# cuda-keyring_1.0-1_all.deb  home/     libx32@  opt/                      run/         tmp/

# %%
"""
wget will connect to the URL specified and download the gcc-8.5.0.tar.gz file to your current working directory.
# !tar xf gcc-8.5.0.tar.gz is a shell command to extract the contents of the gcc-8.5.0.tar.gz archive file, using the tar utility.
"""
# !wget https://ftp.gnu.org/gnu/gcc/gcc-8.5.0/gcc-8.5.0.tar.gz
# !tar xf gcc-8.5.0.tar.gz
# Out:
# --2023-12-06 04:38:22--  https://ftp.gnu.org/gnu/gcc/gcc-8.5.0/gcc-8.5.0.tar.gz
# Resolving ftp.gnu.org (ftp.gnu.org)... 209.51.188.20, 2001:470:142:3::b
# Connecting to ftp.gnu.org (ftp.gnu.org)|209.51.188.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 114434620 (109M) [application/x-gzip]
# Saving to: ‘gcc-8.5.0.tar.gz’
#
# gcc-8.5.0.tar.gz    100%[===================>] 109.13M  30.4MB/s    in 4.2s
#
# 2023-12-06 04:38:27 (25.9 MB/s) - ‘gcc-8.5.0.tar.gz’ saved [114434620/114434620]

# %%
# %ls
# %cd gcc-8.5.0/
# Out:
# bin@                        dev/              lib@     mnt/                      root/  tmp/
# boot/                       etc/              lib32@   NGC-DL-CONTAINER-LICENSE  run/   tools/
# content/                    gcc-8.5.0/        lib64@   opt/                      sbin@  usr/
# cuda-keyring_1.0-1_all.deb  gcc-8.5.0.tar.gz  libx32@  proc/                     srv/   var/
# datalab/                    home/             media/   python-apt/               sys/
# /gcc-8.5.0

# %%
"""
Download the prerequisites of gcc-8.5.0 before compiling and installing gcc-8.5.0
"""
# !./contrib/download_prerequisites
# Out:
# 2023-12-06 04:38:34 URL: ftp://gcc.gnu.org/pub/gcc/infrastructure/gmp-6.1.0.tar.bz2 [2383840] -> "./gmp-6.1.0.tar.bz2" [1]
# 2023-12-06 04:38:36 URL: ftp://gcc.gnu.org/pub/gcc/infrastructure/mpfr-3.1.4.tar.bz2 [1279284] -> "./mpfr-3.1.4.tar.bz2" [1]
# 2023-12-06 04:38:38 URL: ftp://gcc.gnu.org/pub/gcc/infrastructure/mpc-1.0.3.tar.gz [669925] -> "./mpc-1.0.3.tar.gz" [1]
# 2023-12-06 04:38:40 URL: ftp://gcc.gnu.org/pub/gcc/infrastructure/isl-0.18.tar.bz2 [1658291] -> "./isl-0.18.tar.bz2" [1]
# gmp-6.1.0.tar.bz2: OK
# mpfr-3.1.4.tar.bz2: OK
# mpc-1.0.3.tar.gz: OK
# isl-0.18.tar.bz2: OK
# All prerequisites downloaded successfully.

# %%
# !mkdir build
# %cd build
# Out:
# /gcc-8.5.0/build

# %%
"""
# !../configure: Runs the configure script located in the parent directory (..). The ! is typically used in some environments to run a shell command.
-v: Verbose mode. This tells configure to print more information during the process.
--build=x86_64-linux-gnu: Specifies the build system type (here, an x86_64 machine running a GNU/Linux).
--host=x86_64-linux-gnu: Specifies the host system type. This is often the same as the build system for native compilations.
--target=x86_64-linux-gnu: Specifies the target system type. For most users, this is the same as the host.
--prefix=/usr/local/gcc-8.5: This option tells the configure script where to install the compiled program. In this case, it's installing in /usr/local/gcc-8.5.
--enable-checking=release: Enables specific levels of error checking (here, settings suitable for a release build).
--enable-languages=c,c++: This tells the configure script to only build the C and C++ compilers.
--disable-multilib: Disables the building of multilib support. Multilib allows the support of multiple architectures on a single system.
"""
# !../configure -v --build=x86_64-linux-gnu --host=x86_64-linux-gnu --target=x86_64-linux-gnu --prefix=/usr/local/gcc-8.5 --enable-checking=release --enable-languages=c,c++ --disable-multilib
"""
# !make: Runs the make command, which will start the compilation process based on the Makefile generated by the configure script.
-j$(nproc): This tells make to execute multiple jobs simultaneously.
$(nproc) expands to the number of processing units available, as detected by the nproc command, allowing for parallel compilation.
"""
# !make -j$(nproc)
# Out:
# Streaming output truncated to the last 5000 lines.
# libtool: compile:  /gcc-8.5.0/build/./gcc/xgcc -B/gcc-8.5.0/build/./gcc/ -B/usr/local/gcc-8.5/x86_64-linux-gnu/bin/ -B/usr/local/gcc-8.5/x86_64-linux-gnu/lib/ -isystem /usr/local/gcc-8.5/x86_64-linux-gnu/include -isystem /usr/local/gcc-8.5/x86_64-linux-gnu/sys-include -DHAVE_CONFIG_H -I. -I../../../libgomp -I../../../libgomp/config/linux/x86 -I../../../libgomp/config/linux -I../../../libgomp/config/posix -I../../../libgomp -I../../../libgomp/../include -Wall -Werror -pthread -ftls-model=initial-exec -g -O2 -MT sections.lo -MD -MP -MF .deps/sections.Tpo -c ../../../libgomp/sections.c  -fPIC -DPIC -o .libs/sections.o
# ...

# %%
"""
# !sudo make install is a command used to install software that has been compiled from source.
It typically needs to be executed with root privileges (hence sudo) because it often involves writing to directories that are not writable by regular users.
This command is the final step in a typical source compilation and installation process, following the configuration (./configure) and compilation (make) stages.
"""
# !sudo make install
# Out:
# make[1]: Entering directory '/gcc-8.5.0/build'
# /bin/bash ../mkinstalldirs /usr/local/gcc-8.5 /usr/local/gcc-8.5
# mkdir -p -- /usr/local/gcc-8.5 /usr/local/gcc-8.5
# make[2]: Entering directory '/gcc-8.5.0/build/fixincludes'
# rm -rf /usr/local/gcc-8.5/libexec/gcc/x86_64-linux-gnu/8.5.0/install-tools
# /bin/bash ../../fixincludes/../mkinstalldirs /usr/local/gcc-8.5/libexec/gcc/x86_64-linux-gnu/8.5.0/install-tools
# mkdir -p -- /usr/local/gcc-8.5/libexec/gcc/x86_64-linux-gnu/8.5.0/install-tools
# /bin/bash ../../fixincludes/../mkinstalldirs /usr/local/gcc-8.5/lib/gcc/x86_64-linux-gnu/8.5.0/install-tools/include
# mkdir -p -- /usr/local/gcc-8.5/lib/gcc/x86_64-linux-gnu/8.5.0/install-tools/include
# /usr/bin/install -c -m 644 ../../fixincludes/README-fixinc \
#   /usr/local/gcc-8.5/lib/gcc/x86_64-linux-gnu/8.5.0/install-tools/include/README
# /usr/bin/install -c fixinc.sh /usr/local/gcc-8.5/libexec/gcc/x86_64-linux-gnu/8.5.0/install-tools/fixinc.sh
# ...

# %%
"""
this command is configuring your system to use GCC and G++ version 8.5, located in /usr/local/gcc-8.5/bin/, and setting their priorities to 60.
When you run gcc or g++, the system will use these versions unless a version with a higher priority is installed.
"""
# !sudo update-alternatives --install /usr/bin/gcc gcc /usr/local/gcc-8.5/bin/gcc 60 --slave /usr/bin/g++ g++ /usr/local/gcc-8.5/bin/g++
# Out:
# update-alternatives: using /usr/local/gcc-8.5/bin/gcc to provide /usr/bin/gcc (gcc) in auto mode

# %%
"""
this command is to check and ensure that the correct gcc version (8.5.0) is installed
"""
# !gcc --version
# Out:
# gcc (GCC) 8.5.0
# Copyright (C) 2018 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !pwd
# Out:
# /gcc-8.5.0/build

# %%
# %cd ..
# %cd ..
# Out:
# /gcc-8.5.0
# /

# %% [markdown]
# # Install Required Python Libraries for DeepModal

# %%
# !pip install torch torchvision torchaudio torch_scatter
# !pip install scipy matplotlib numba tensorboard tqdm meshio pycuda
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torch_scatter: filename=torch_scatter-2.1.2-cp310-cp310-linux_x86_64.whl size=3529550 sha256=989be011feb4eb12550afbf6d40243aa2502dfbe68ea95324ad80ebf4d0cb106
#   Stored in directory: /root/.cache/pip/wheels/92/f1/2b/3b46d54b134259f58c8363568569053248040859b1a145b3ce
# Successfully built torch_scatter
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.7/167.7 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 17.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 13.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Install Minkowski Engine

# %%
"""
this command is used to install the development files for OpenBLAS on a Debian-based Linux system.
OpenBLAS is an open-source implementation of the BLAS (Basic Linear Algebra Subprograms) and LAPACK (Linear Algebra Package) libraries,
which are widely used in scientific computing for performing basic vector and matrix operations.
"""
# !sudo apt install libopenblas-dev
"""
this command is used to clone the MinkowskiEngine repository for installation
"""
# !git clone https://github.com/NVIDIA/MinkowskiEngine.git
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libopenblas-dev is already the newest version (0.3.20+ds-1).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# Cloning into 'MinkowskiEngine'...
# remote: Enumerating objects: 7355, done.
# remote: Counting objects: 100% (589/589), done.
# remote: Compressing objects: 100% (244/244), done.
# remote: Total 7355 (delta 368), reused 546 (delta 341), pack-reused 6766
# Receiving objects: 100% (7355/7355), 14.92 MiB | 26.95 MiB/s, done.
# Resolving deltas: 100% (5736/5736), done.

# %%
"""
# !export CXX=g++-8: This line sets an environment variable CXX to g++-8.
Environment variables are a set of dynamic values that can affect the way running processes on a computer will behave.
Here, CXX is used to specify the C++ compiler to be used, and g++-8 refers to a specific version of the GNU C++ compiler.

# !export CUDA_HOME=/usr/loca/cuda-11.1: This sets another environment variable, CUDA_HOME.
This variable typically points to the installation directory of CUDA (Compute Unified Device Architecture), a parallel computing platform and API model created by Nvidia.
Here, it is being set to /usr/loca/cuda-11.1, which should be the directory where CUDA version 11.1 is installed.

# !export MAX_JOBS=8;: This command sets the MAX_JOBS environment variable to 8.
This is often used to limit the number of jobs or processes that can run simultaneously. In the context of software compilation,
it's typically used to limit the number of compiler jobs running in parallel, to match the number of available processor cores, for efficient compilation.

# !python setup.py install --blas_include_dirs=${CONDA_PREFIX}/include --blas=openblas:
This is a command to install a Python package, typically one that is being developed locally.

python setup.py install is a standard way to install Python packages from source. It runs the setup.py script, which contains instructions for installing the package.
--blas_include_dirs=${CONDA_PREFIX}/include specifies the include directories for BLAS (Basic Linear Algebra Subprograms) library installations.
${CONDA_PREFIX} is an environment variable that points to the root of the current Conda environment.
--blas=openblas indicates that the package should be compiled using OpenBLAS, an open-source implementation of BLAS.
"""
# %cd /
# %cd MinkowskiEngine
# !export CXX=g++-8
# !export CUDA_HOME=/usr/local/cuda-11.1
# !export MAX_JOBS=8;
# !python setup.py install --blas_include_dirs=${CONDA_PREFIX}/include --blas=openblas
# Out:
# /
# /MinkowskiEngine
# WARNING: Skipping MinkowskiEngine as it is not installed.
# --------------------------------
# | CUDA compilation set         |
# --------------------------------
#
# Using BLAS=openblas
# Using the default compiler
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# ...

# %% [markdown]
# # Train DeepModal Neural Network

# %%
# %cd /
# %cd content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset_scripts
# Out:
# /
# /content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset_scripts

# %%
from pathlib import Path
import os
for num in range(0, 4):
    formatted_num = str(num).zfill(4)
    print(f"formatted_num is : {formatted_num}")
    for num1 in range(0, 10000):
        formatted_num_2 = str(num1).zfill(4)
        print(f"formatted_num_2 is : {formatted_num_2}")
        formatted_num_3 = formatted_num + formatted_num_2
        print(f"formatted_num_3 is : {formatted_num_3}")
        folder_path = Path(f'../dataset/mesh/abc_{formatted_num}_obj_v00/{formatted_num_3}/')
        print(f"folder_path is : {folder_path}")
        if folder_path.is_dir():
            if not any (folder_path.iterdir()):
                print(f"The folder '{folder_path} is empty")
            else:
                print(f"The folder '{folder_path}' is not empty")
                folder_path = Path(f'../dataset/mesh/abc_{formatted_num}_obj_v00/{formatted_num_3}/*')
                print(folder_path)
                # !python voxelize.py "{folder_path}" "../dataset/voxel"
        else:
            print(f"The folder '{folder_path}' does not exist'")

# voxel_folder = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset/voxel')
# try:
#     files = [f for f in os.listdir(voxel_folder) if os.path.isfile(os.path.join(voxel_folder, f))]
#     number_of_files = len(files)
#     print(f"There are {number_of_files} files in the folder '{voxel_folder}'")
# except FileNotFoundError:
#     print(f"The folder '{voxel_folder}' does not exist.")

# %%
voxel_folder = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset/voxel/')
eigen_folder = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset/eigen/')
# try:
#     files = [f for f in os.listdir(eigen_folder) if os.path.isfile(os.path.join(eigen_folder, f))]
#     number_of_files = len(files)
#     print(f"There are {number_of_files} files in the folder '{eigen_folder}'")
# except FileNotFoundError:
#     print(f"The folder '{eigen_folder}' does not exist.")

for filename in os.listdir(voxel_folder):
    print(f"filename is : {filename}, {type(filename)}")
    eigen_file_name = filename.replace(".npy", ".npz")
    print(f"eigen file name is : {eigen_file_name}, {type(eigen_file_name)}")
    file_path = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset/voxel/{filename}')
    eigen_file_path = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset/eigen/{eigen_file_name}')
    if os.path.exists(eigen_file_path):
        print(f'file already exists')
        continue
    else:
        print(f'file does not exist yet')
        # !python modalAnalysis.py "{file_path}" "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset/eigen/"

# %%
eigen_folder = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset/eigen/')
deep_modal_folder = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset/deepmodal/')
# try:
#     files = [f for f in os.listdir(deep_modal_folder) if os.path.isfile(os.path.join(deep_modal_folder, f))]
#     number_of_files = len(files)
#     print(f"There are {number_of_files} files in the deepmodal folder '{deep_modal_folder}'")
# except FileNotFoundError:
#     print(f"The folder '{deep_modal_folder}' does not exist.")

for filename in os.listdir(eigen_folder):
    print(f'eigen file name is : {filename}')
    deep_modal_filename = filename.replace('.npz', '.pt')
    print(f"deep modal file name is : {deep_modal_filename}, {type(deep_modal_filename)}")
    eigen_file_path = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset/eigen/{filename}')
    deep_modal_file_path = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset/deepmodal/{deep_modal_filename}')
    if os.path.exists(deep_modal_file_path):
        print(f'file already exists')
        continue
    else:
        print(f'file does not exist yet')
        # !python deepModal.py "{eigen_file_path}" "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset/deepmodal"

# %%
# !python splitDataset.py "../dataset/deepmodal/*.pt"

# %%
# %cd ../deepmodal

# %%
# !python train.py --dataset "../dataset/deepmodal" --tag default_tag --net defaultUnet --cuda 0

# %% [markdown]
# # Test the trained DeepModal Neural Network

# %%
import MinkowskiEngine as ME
import sys
import torch
from pathlib import Path
import os
sys.path.append('/content/drive/MyDrive/Y4S1_FYP/NeuralSound/')
import src.net.eigennet
device = torch.device('cuda:0')

# %%
model = src.net.eigennet.defaultUnet(in_channels=24*32*2, out_channels=24*32*2, linear = False)
# Out:
# non linear network

# %%
weights = torch.load('/content/drive/MyDrive/Y4S1_FYP/NeuralSound/deepmodal/weights/default_tag.pt')

# %%
model.load_state_dict(weights)
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# defaultUnet(
#   (block0): Sequential(
#     (0): BasicBlock(
#       (conv1): MinkowskiConvolution(in=1536, out=24, kernel_size=[3, 3, 3], stride=[1, 1, 1], dilation=[1, 1, 1])
#       (norm1): MinkowskiBatchNorm(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): MinkowskiConvolution(in=24, out=24, kernel_size=[3, 3, 3], stride=[1, 1, 1], dilation=[1, 1, 1])
#       (norm2): MinkowskiBatchNorm(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): MinkowskiReLU()
#       (downsample): Sequential(
#         (0): MinkowskiConvolution(in=1536, out=24, kernel_size=[1, 1, 1], stride=[1, 1, 1], dilation=[1, 1, 1])
#       )
#     )
#   )
#   (down0): Sequential(
#     (0): MinkowskiConvolution(in=24, out=24, kernel_size=[2, 2, 2], stride=[2, 2, 2], dilation=[1, 1, 1])
#   )
#   (block1): Sequential(
#     (0): BasicBlock(
# ...

# %%
from deepmodal.dataset import DeepModalDataset, deepmodal_collation_fn
from torch.utils.data import Dataset
from src.net.trainer_template import Config
import src.net.eigennet as eigennet
from tqdm import tqdm
from deepmodal.train import loss_fun
from torch_scatter import scatter
from torch.utils.data import DataLoader
from pathlib import Path

# %%
def forward_fun_new(items, n):
    coords, edge_shifted, ind_lst, vecs, mask, filename = items
    vert_num = ind_lst[-1]
    x0 = torch.randn(vert_num*3, n).to(device)
    x1 = net(coords, x0, edge_shifted, n)
    vecs = vecs[0].to(device)
    mask = mask[0].to(device)
    err_vecs = torch.norm(vecs - x1[:,:n//2]) / torch.norm(vecs)
    err_mask = torch.norm(mask - x1[:,n//2:]) / torch.norm(mask)
    predicted_vecs = x1[:,:n//2]
    predicted_mask = x1[:,n//2:]
    return predicted_vecs, predicted_mask

# %%
def net(coords, x, edge, n):
    vert_num = x.shape[0]//3
    x = x.reshape(vert_num, 3*n)
    feats_in = vert2vox(x, edge)  # [voxel_num, 8*3*n]
    voxel_num = feats_in.shape[0]
    feats_in = feats_in.reshape(voxel_num, 8*3*n)
    bcoords = ME.utils.batched_coordinates(coords).to(device)
    sparse_tensor = ME.SparseTensor(feats_in, bcoords)
    output = config.net(sparse_tensor).F
    output = vox2vert(output, edge, 'mean').reshape(vert_num*3, n)
    return output

# %%
def vert2vox(x, edge):
    '''
    input:
        x:      [vert_num, feature_num]
        edge:   [voxel_num, 8]
    return:
        x_:     [voxel_num, 8*feature_num]
    '''
    voxel_num = edge.shape[0]
    feature_num = x.shape[-1]
    return x[edge].reshape(voxel_num, 8*feature_num)

# %%
def vox2vert(x, edge, reduce = 'sum'):
    '''
    input:
        x:      [voxel_num, 8*feature_num]
        edge:   [voxel_num, 8]
    return:
        x_:     [vert_num, feature_num]
    '''
    voxel_num = x.shape[0]
    feature_num = x.shape[-1]//8
    return scatter(
            x.reshape(voxel_num*8, feature_num),
            edge.reshape(-1),
            dim=0,
            reduce=reduce
        )

# %%
def get_loader(phase):
    dataset = config.CustomDataset(config.dataset_root_dir, phase)
    if len(dataset) < config.BATCH_SIZE:
        drop_last = False
    else:
        drop_last = True
    loader = DataLoader(dataset, batch_size=config.BATCH_SIZE, shuffle=True,
                        collate_fn=config.custom_collation_fn, drop_last=drop_last, num_workers=config.dataset_worker_num)
    return loader

# %%
def forward_and_backward(loader, n):
    total_loss = []
    loss_item = {}
    config.idx_in_epoch = 0
    print(f'Phase: {config.phase}')
    for items_ in tqdm(loader):
        items = []
        loss_sum = 0
        for item in items_:
            if isinstance(item, torch.Tensor):
                item = item.to(config.device, non_blocking=True)
            items.append(item)
        predicted_vecs, predicted_mask = config.forward_fun(items, n)
    return predicted_vecs, predicted_mask

# %% [markdown]
# # First Test Instance: Vase

# %%
# !pip install librosa
import librosa
import numpy as np
import soundfile as sf

# %%
config = Config()

# %%
config.dataset_root_dir = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/vase/')
device = torch.device('cuda:0')
config.device = device
config.CustomDataset = DeepModalDataset
config.custom_collation_fn = deepmodal_collation_fn
config.forward_fun = forward_fun_new
config.loss_fun = loss_fun
config.phase = 'test'
config.diag = False
config.nonlinear = True
n = 32*2
config.net = model
config.net.to(config.device)
config.BATCH_SIZE = 1
config.dataset_worker_num = 8

# %%
# %cd /content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset_scripts/
# Out:
# /content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset_scripts

# %%
# !python voxelize.py '/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/vase/vase.obj' "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/vase/"
# Out:
# file_number: 1
# 100% 1/1 [00:01<00:00,  1.93s/it]

# %%
# !python modalAnalysis.py "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/vase/vase.npy" "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/vase/"
# Out:
# 100% 1/1 [00:06<00:00,  6.68s/it]

# %%
# !python deepModal.py "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/vase/vase.npz" "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/vase/"
# Out:
# 100% 1/1 [00:00<00:00,  1.11it/s]

# %%
# %cd /content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/vase
# Out:
# /content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/vase

# %%
with open('test.txt', 'w') as f:
    f.write('vase.pt')

# %%
loader = get_loader(config.phase)
# Out:
# test set size:  1

# %%
predicted_vecs, predicted_mask = forward_and_backward(loader, n)
# Out:
# Phase: test
# 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]

# %%
numpy_predicted_vecs = predicted_vecs.cpu().detach().numpy()
numpy_predicted_mask = predicted_mask.cpu().detach().numpy()
sr = 22050

# %%
inverse_predicted_vecs = torch.exp(predicted_vecs)

# %%
numpy_inverse_predicted_vecs = inverse_predicted_vecs.cpu().detach().numpy()

# %%
inverse_filtered_audio = numpy_inverse_predicted_vecs * numpy_predicted_mask

# %%
reconstructed_inverse_audio = librosa.istft(inverse_filtered_audio)
sf.write(f'reconstructed_inverse_audio_{sr}.wav', reconstructed_inverse_audio, sr)

# %% [markdown]
# # Second test instance: Glass Bottle

# %%
config = Config()

# %%
config.dataset_root_dir = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/glass_bottle/')
device = torch.device('cuda:0')
config.device = device
config.CustomDataset = DeepModalDataset
config.custom_collation_fn = deepmodal_collation_fn
config.forward_fun = forward_fun_new
config.loss_fun = loss_fun
config.phase = 'test'
config.diag = False
config.nonlinear = True
n = 32*2
config.net = model
config.net.to(config.device)
config.BATCH_SIZE = 1
config.dataset_worker_num = 8

# %%
# %cd /content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset_scripts/
# Out:
# /content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset_scripts

# %%
# !python voxelize.py '/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/glass_bottle/glass_bottle.obj' "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/glass_bottle/"
# Out:
# file_number: 1
# 100% 1/1 [00:02<00:00,  2.27s/it]

# %%
# !python modalAnalysis.py "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/glass_bottle/glass_bottle.npy" "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/glass_bottle/"
# Out:
# 100% 1/1 [00:06<00:00,  6.20s/it]

# %%
# !python deepModal.py "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/glass_bottle/glass_bottle.npz" "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/glass_bottle/"
# Out:
# 100% 1/1 [00:01<00:00,  1.54s/it]

# %%
# %cd /content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/glass_bottle/
# Out:
# /content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/glass_bottle

# %%
with open('test.txt', 'w') as f:
    f.write('glass_bottle.pt')

# %%
loader = get_loader(config.phase)
# Out:
# test set size:  1

# %%
predicted_vecs, predicted_mask = forward_and_backward(loader, n)
# Out:
# Phase: test
# 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]

# %%
numpy_predicted_vecs = predicted_vecs.cpu().detach().numpy()
numpy_predicted_mask = predicted_mask.cpu().detach().numpy()
sr = 22050

# %%
inverse_predicted_vecs = torch.exp(predicted_vecs)

# %%
numpy_inverse_predicted_vecs = inverse_predicted_vecs.cpu().detach().numpy()

# %%
inverse_filtered_audio = numpy_inverse_predicted_vecs * numpy_predicted_mask

# %%
reconstructed_inverse_audio = librosa.istft(inverse_filtered_audio)
sf.write(f'reconstructed_inverse_audio_{sr}.wav', reconstructed_inverse_audio, sr)

# %% [markdown]
# # Third Test Instance: Wooden Door

# %%
config = Config()

# %%
config.dataset_root_dir = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/styrofoam_cup/')
device = torch.device('cuda:0')
config.device = device
config.CustomDataset = DeepModalDataset
config.custom_collation_fn = deepmodal_collation_fn
config.forward_fun = forward_fun_new
config.loss_fun = loss_fun
config.phase = 'test'
config.diag = False
config.nonlinear = True
n = 32*2
config.net = model
config.net.to(config.device)
config.BATCH_SIZE = 1
config.dataset_worker_num = 8

# %%
# %cd /content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset_scripts/
# Out:
# /content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset_scripts

# %%
# !python voxelize.py '/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/styrofoam_cup/styrofoam_cup.obj' "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/styrofoam_cup/"
# Out:
# file_number: 1
# 100% 1/1 [00:02<00:00,  2.26s/it]

# %%
# !python modalAnalysis.py "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/styrofoam_cup/styrofoam_cup.npy" "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/styrofoam_cup/"
# Out:
# 100% 1/1 [00:03<00:00,  3.01s/it]

# %%
# !python deepModal.py "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/styrofoam_cup/styrofoam_cup.npz" "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/styrofoam_cup/"
# Out:
# 100% 1/1 [00:00<00:00,  1.20it/s]

# %%
# %cd /content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/styrofoam_cup/
# Out:
# /content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/styrofoam_cup

# %%
with open('test.txt', 'w') as f:
    f.write('styrofoam_cup.pt')

# %%
loader = get_loader(config.phase)
# Out:
# test set size:  1

# %%
predicted_vecs, predicted_mask = forward_and_backward(loader, n)
# Out:
# Phase: test
# 100%|██████████| 1/1 [00:00<00:00,  2.02it/s]

# %%
numpy_predicted_vecs = predicted_vecs.cpu().detach().numpy()
numpy_predicted_mask = predicted_mask.cpu().detach().numpy()
sr = 22050

# %%
inverse_predicted_vecs = torch.exp(predicted_vecs)

# %%
numpy_inverse_predicted_vecs = inverse_predicted_vecs.cpu().detach().numpy()

# %%
inverse_filtered_audio = numpy_inverse_predicted_vecs * numpy_predicted_mask

# %%
reconstructed_inverse_audio = librosa.istft(inverse_filtered_audio)
sf.write(f'reconstructed_inverse_audio_{sr}.wav', reconstructed_inverse_audio, sr)

# %% [markdown]
# # Fourth Test Instance: Soccer Ball

# %%
config = Config()

# %%
config.dataset_root_dir = Path(f'/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/soccer_ball/')
device = torch.device('cuda:0')
config.device = device
config.CustomDataset = DeepModalDataset
config.custom_collation_fn = deepmodal_collation_fn
config.forward_fun = forward_fun_new
config.loss_fun = loss_fun
config.phase = 'test'
config.diag = False
config.nonlinear = True
n = 32*2
config.net = model
config.net.to(config.device)
config.BATCH_SIZE = 1
config.dataset_worker_num = 8

# %%
# %cd /content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset_scripts/
# Out:
# /content/drive/MyDrive/Y4S1_FYP/NeuralSound/dataset_scripts

# %%
# !python voxelize.py '/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/soccer_ball/soccer_ball.obj' "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/soccer_ball/"
# Out:
# file_number: 1
# 100% 1/1 [00:02<00:00,  2.05s/it]

# %%
# !python modalAnalysis.py "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/soccer_ball/soccer_ball.npy" "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/soccer_ball/"
# Out:
# 100% 1/1 [00:10<00:00, 10.40s/it]

# %%
# !python deepModal.py "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/soccer_ball/soccer_ball.npz" "/content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/soccer_ball/"
# Out:
# 100% 1/1 [00:00<00:00,  1.07it/s]

# %%
# %cd /content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/soccer_ball/
# Out:
# /content/drive/MyDrive/Y4S1_FYP/NeuralSound/test_obj/soccer_ball

# %%
with open('test.txt', 'w') as f:
    f.write('soccer_ball.pt')

# %%
loader = get_loader(config.phase)
# Out:
# test set size:  1

# %%
predicted_vecs, predicted_mask = forward_and_backward(loader, n)
# Out:
# Phase: test
# 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]

# %%
numpy_predicted_vecs = predicted_vecs.cpu().detach().numpy()
numpy_predicted_mask = predicted_mask.cpu().detach().numpy()
sr = 22050

# %%
inverse_predicted_vecs = torch.exp(predicted_vecs)

# %%
numpy_inverse_predicted_vecs = inverse_predicted_vecs.cpu().detach().numpy()

# %%
inverse_filtered_audio = numpy_inverse_predicted_vecs * numpy_predicted_mask

# %%
reconstructed_inverse_audio = librosa.istft(inverse_filtered_audio)
sf.write(f'reconstructed_inverse_audio_{sr}.wav', reconstructed_inverse_audio, sr)
